# %% [markdown]
# # Preliminary Data Analysis

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#file = 'C:\\Users\\Chung-Tseng Wang\\Desktop\\Census-Income-with-Tree-Based-Models\\data\\raw\\adult_csv.csv'
file = '//Users//chung-tsengwang//Desktop//Github Repo//Census-Income-with-Tree-Based-Models//data//raw//adult_csv.csv'
adult = pd.read_csv(file)
adult.head()
# Out:
#    age         workclass  fnlwgt  education  education-num  \
# 0    2         State-gov   77516  Bachelors             13
# 1    3  Self-emp-not-inc   83311  Bachelors             13
# 2    2           Private  215646    HS-grad              9
# 3    3           Private  234721       11th              7
# 4    1           Private  338409  Bachelors             13
#
#        marital-status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capitalgain  capitalloss  hoursperweek native-country  class
# 0            1            0             2  United-States  <=50K
# 1            0            0             0  United-States  <=50K
# 2            0            0             2  United-States  <=50K
# 3            0            0             2  United-States  <=50K
# 4            0            0             2           Cuba  <=50K

# %%
adult.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48842 entries, 0 to 48841
# Data columns (total 15 columns):
# age               48842 non-null int64
# workclass         48842 non-null object
# fnlwgt            48842 non-null int64
# education         48842 non-null object
# education-num     48842 non-null int64
# marital-status    48842 non-null object
# occupation        48842 non-null object
# relationship      48842 non-null object
# race              48842 non-null object
# sex               48842 non-null object
# capitalgain       48842 non-null int64
# capitalloss       48842 non-null int64
# hoursperweek      48842 non-null int64
# native-country    48842 non-null object
# class             48842 non-null object
# dtypes: int64(6), object(9)
# memory usage: 5.6+ MB

# %%
adult.describe()
# Out:
#                 age        fnlwgt  education-num   capitalgain   capitalloss  \
# count  48842.000000  4.884200e+04   48842.000000  48842.000000  48842.000000
# mean       1.771078  1.896641e+05      10.078089      0.200319      0.114942
# std        1.295378  1.056040e+05       2.570973      0.746182      0.556924
# min        0.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%        1.000000  1.175505e+05       9.000000      0.000000      0.000000
# 50%        2.000000  1.781445e+05      10.000000      0.000000      0.000000
# 75%        3.000000  2.376420e+05      12.000000      0.000000      0.000000
# max        4.000000  1.490400e+06      16.000000      4.000000      4.000000
#
#        hoursperweek
# count  48842.000000
# mean       1.950698
# std        0.897038
# min        0.000000
# 25%        2.000000
# 50%        2.000000
# 75%        2.000000
# max        4.000000

# %%
for n in adult.columns:
    count = adult[n][adult[n] == '?'].count()
    print(str(n)+ ' :' + str(count))
# Out:
# age :0
# workclass :2799
# fnlwgt :0
# education :0
# education-num :0
# marital-status :0
# occupation :2809
# relationship :0
# race :0
# sex :0
# capitalgain :0
# capitalloss :0
# hoursperweek :0
# native-country :857
# class :0

# %% [markdown]
# ## Impute Missing Values with Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

# %%
#One Hot Encoding Function 
def onehotencoder(df, df_cols):
    
    df_1 = adult_data = df.drop(columns = df_cols, axis = 1)
    df_2 = pd.get_dummies(df[df_cols])
    
    return (pd.concat([df_1, df_2], axis=1, join='inner'))

# %%
def logimpute(col):
    test_data = adult[(adult[col].values == '?')].copy()
    test_label = test_data[col]

    train_data = adult[(adult[col].values != '?')].copy()
    train_label = train_data[col]

    test_data.drop(columns = [str(col)], inplace = True)
    train_data.drop(columns = [str(col)], inplace = True)

    train_data = onehotencoder(train_data, train_data.select_dtypes('object').columns)
    test_data = onehotencoder(test_data, test_data.select_dtypes('object').columns)

    missing_cols = set(train_data.columns) - set(test_data.columns)
    for c in missing_cols:
        test_data[c] = 0
    test_data = test_data[train_data.columns]

    log_reg = LogisticRegression()
    log_reg.fit(train_data, train_label)
    log_reg_pred = log_reg.predict(test_data)

    adult.loc[(adult[col].values == '?'),str(col)] = log_reg_pred

# %%
impute_cols = ['workclass', 'occupation', 'native-country']
for n in impute_cols:
    logimpute(n)
# Out:
# /Users/chung-tsengwang/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /Users/chung-tsengwang/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/logistic.py:469: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /Users/chung-tsengwang/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /Users/chung-tsengwang/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/logistic.py:469: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /Users/chung-tsengwang/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /Users/chung-tsengwang/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/logistic.py:469: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)

# %%
for n in adult.columns:
    count = adult[n][adult[n] == '?'].count()
    print(str(n)+ ' :' + str(count))
# Out:
# age :0
# workclass :0
# fnlwgt :0
# education :0
# education-num :0
# marital-status :0
# occupation :0
# relationship :0
# race :0
# sex :0
# capitalgain :0
# capitalloss :0
# hoursperweek :0
# native-country :0
# class :0
# /Users/chung-tsengwang/anaconda3/lib/python3.6/site-packages/pandas/core/ops/__init__.py:1115: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)

# %%
adult.head(200)
# Out:
#      age         workclass  fnlwgt     education  education-num  \
# 0      2         State-gov   77516     Bachelors             13
# 1      3  Self-emp-not-inc   83311     Bachelors             13
# 2      2           Private  215646       HS-grad              9
# 3      3           Private  234721          11th              7
# 4      1           Private  338409     Bachelors             13
# ..   ...               ...     ...           ...            ...
# 195    0           Private  197387       5th-6th              3
# 196    2           Private   99374  Some-college             10
# 197    2       Federal-gov   56795       Masters             14
# 198    1           Private  138992       Masters             14
# 199    0  Self-emp-not-inc   32921       HS-grad              9
#
#          marital-status         occupation    relationship   race     sex  \
# 0         Never-married       Adm-clerical   Not-in-family  White    Male
# 1    Married-civ-spouse    Exec-managerial         Husband  White    Male
# 2              Divorced  Handlers-cleaners   Not-in-family  White    Male
# 3    Married-civ-spouse  Handlers-cleaners         Husband  Black    Male
# 4    Married-civ-spouse     Prof-specialty            Wife  Black  Female
# ..                  ...                ...             ...    ...     ...
# 195  Married-civ-spouse   Transport-moving  Other-relative  White    Male
# 196            Divorced       Craft-repair   Not-in-family  White    Male
# 197       Never-married    Exec-managerial   Not-in-family  White  Female
# 198  Married-civ-spouse     Prof-specialty  Other-relative  White    Male
# 199       Never-married              Sales   Not-in-family  White    Male
#
#      capitalgain  capitalloss  hoursperweek native-country  class
# 0              1            0             2  United-States  <=50K
# 1              0            0             0  United-States  <=50K
# 2              0            0             2  United-States  <=50K
# 3              0            0             2  United-States  <=50K
# 4              0            0             2           Cuba  <=50K
# ..           ...          ...           ...            ...    ...
# 195            0            0             2         Mexico  <=50K
# 196            0            0             2  United-States  <=50K
# 197            4            0             3  United-States   >50K
# 198            2            0             2  United-States   >50K
# 199            0            0             2  United-States  <=50K
#
# [200 rows x 15 columns]

# %% [markdown]
# ## Correlation Matrix

# %%
import seaborn as sns
sns.set(style="dark")
corr = adult.corr()
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True
f, ax = plt.subplots(figsize=(15, 10))
cmap = sns.diverging_palette(240, 10, as_cmap=True)
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0, square=True,linewidths=.5, cbar_kws={"shrink": .5})
plt.title('Correlation Matrix')
plt.show()

# %%
adult.to_csv('processed.csv')
